# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image=cv2.imread('2.jpg')

gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
#cv2.imshow('original image',image)
ret, thresh=cv2.threshold(gray,176,255,0)
contours, hierarchy = cv2.findContours(thresh.copy(), cv2.RETR_CCOMP, cv2.CHAIN_APPROX_NONE)
n=len(contours)-1
contours=sorted(contours,key=cv2.contourArea,reverse=False)[:n]
#print(contours)
print('Numbers of contours found=' + str(len(contours)))
# Out:
# Numbers of contours found=1337

# %%
for c in contours:
    hull=cv2.convexHull(c)
    cv2.drawContours(image,[hull],0,(0,255,0),2)
cv2.imshow('convex hull',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for c in range(len(contours)):
    # Since the image only has one contour, grab the first contour
    cnt = contours[c]
    # Get the required hull
    hull = cv2.convexHull(cnt)
    # draw the hull
    cv2.drawContours(hull_img, [hull], 0 , (0,0,220), 3)
    cv2.putText(hull_img, str(3), (contours[0,0,0], contours[0,0,1]-10), cv2.FONT_HERSHEY_SIMPLEX, 1.4, (0, 255, 0),4)
    # draw the contour
    cv2.drawContours(contour_img, [cnt], 0, (0,0,220), 3)
#cv2.imshow('Contours with bounding box', image)
cv2.imshow('Contours with bounding box', hull_img)
cv2.waitKey(0)
#cv2.imshow('Contours with bounding box', contour_img)
#cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-735f025a2702> in <module>
#       6     # draw the hull
#       7     cv2.drawContours(hull_img, [hull], 0 , (0,0,220), 3)
# ----> 8     cv2.putText(hull_img, str(3), (contours[0,0,0], contours[0,0,1]-10), cv2.FONT_HERSHEY_SIMPLEX, 1.4, (0, 255, 0),4)
#       9     # draw the contour
#      10     cv2.drawContours(contour_img, [cnt], 0, (0,0,220), 3)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
import imutils

# %%
hull_img = image.copy()
contour_img = image.copy()
 
# Convert the image to gray-scale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
 
# Create a binary thresholded image
_, binary = cv2.threshold(gray, 230, 255, cv2.THRESH_BINARY_INV)
 
# Find the contours from the thresholded image
contours, hierarchy = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
 
# Since the image only has one contour, grab the first contour
cnt = contours[45]
 
# Get the required hull
hull = cv2.convexHull(cnt)
 
# draw the hull
cv2.drawContours(hull_img, [hull], 0 , (0,0,220), 3) 
 
# draw the contour
cv2.drawContours(contour_img, [cnt], 0, (0,0,220), 3)
 
plt.figure(figsize=[18,18])
plt.subplot(131);plt.imshow(image[:,:,::-1]);plt.title("Original Image");plt.axis('off')
plt.subplot(132);plt.imshow(contour_img[:,:,::-1]);plt.title("Contour");plt.axis('off');
plt.subplot(133);plt.imshow(hull_img[:,:,::-1]);plt.title("Convex Hull");plt.axis('off');
